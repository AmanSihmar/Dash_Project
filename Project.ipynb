# %%
# !dir C:\Users\Apex\Downloads\SAD\Dash_Project\*.csv
# Out:
#  Volume in drive C is Boot
#  Volume Serial Number is CC2A-116A
#
#  Directory of C:\Users\Apex\Downloads\SAD\Dash_Project
#
# 05-11-2016  17:05        14,010,009 deliveries.csv
# 05-11-2016  17:05           105,993 matches.csv
# 26-05-2017  12:32            69,453 match_detail.csv
# 25-05-2017  17:57         6,896,576 Player_details.csv
#                4 File(s)     21,082,031 bytes
#                0 Dir(s)  51,058,991,104 bytes free

# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
file1 = pd.read_csv('C:/Users/Apex/Downloads/SAD/Dash_Project/deliveries.csv')

# %%
file1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0         1       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 1         1       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 2         1       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 3         1       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 4         1       1  Kolkata Knight Riders  Royal Challengers Bangalore     1
#
#    ball      batsman  non_striker   bowler  wide_runs  bye_runs  legbye_runs  \
# 0     1   SC Ganguly  BB McCullum  P Kumar          0         0            1
# 1     2  BB McCullum   SC Ganguly  P Kumar          0         0            0
# 2     3  BB McCullum   SC Ganguly  P Kumar          1         0            0
# 3     4  BB McCullum   SC Ganguly  P Kumar          0         0            0
# 4     5  BB McCullum   SC Ganguly  P Kumar          0         0            0
#
# ...

# %%
details=pd.DataFrame(file1)

# %%
del details['is_super_over']

# %%
details=details.drop(['batting_team','bowling_team','non_striker','legbye_runs','penalty_runs','wide_runs','bye_runs','noball_runs','extra_runs','inning'],axis=1)

# %%
details.head()
# Out:
#    match_id  over  ball      batsman   bowler  batsman_runs  total_runs  \
# 0         1     1     1   SC Ganguly  P Kumar             0           1
# 1         1     1     2  BB McCullum  P Kumar             0           0
# 2         1     1     3  BB McCullum  P Kumar             0           1
# 3         1     1     4  BB McCullum  P Kumar             0           0
# 4         1     1     5  BB McCullum  P Kumar             0           0
#
#   player_dismissed dismissal_kind fielder
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN
# 3              NaN            NaN     NaN
# 4              NaN            NaN     NaN

# %%
details.rename(columns=lambda x: x[0:].upper(), inplace=True)

# %%
details.head()
# Out:
#    MATCH_ID  OVER  BALL      BATSMAN   BOWLER  BATSMAN_RUNS  TOTAL_RUNS  \
# 0         1     1     1   SC Ganguly  P Kumar             0           1
# 1         1     1     2  BB McCullum  P Kumar             0           0
# 2         1     1     3  BB McCullum  P Kumar             0           1
# 3         1     1     4  BB McCullum  P Kumar             0           0
# 4         1     1     5  BB McCullum  P Kumar             0           0
#
#   PLAYER_DISMISSED DISMISSAL_KIND FIELDER
# 0              NaN            NaN     NaN
# 1              NaN            NaN     NaN
# 2              NaN            NaN     NaN
# 3              NaN            NaN     NaN
# 4              NaN            NaN     NaN

# %%
details.to_csv('Player_details1.csv')

# %%
file2 = pd.read_csv('C:/Users/Apex/Downloads/SAD/Dash_Project/matches.csv')

# %%
file2.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
matches=pd.DataFrame(file2)

# %%
matches= matches.drop(['result','city','dl_applied','venue','umpire1','umpire2','umpire3','season','team1','team2','win_by_runs','win_by_wickets','toss_decision'],axis=1)

# %%
matches.rename(columns=lambda x: x[0:].upper(), inplace=True)

# %%
matches.head()
# Out:
#    ID  SEASON        DATE                  TEAM1                        TEAM2  \
# 0   1    2008  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore
# 1   2    2008  2008-04-19    Chennai Super Kings              Kings XI Punjab
# 2   3    2008  2008-04-19       Rajasthan Royals             Delhi Daredevils
# 3   4    2008  2008-04-20         Mumbai Indians  Royal Challengers Bangalore
# 4   5    2008  2008-04-20        Deccan Chargers        Kolkata Knight Riders
#
#                    TOSS_WINNER TOSS_DECISION                       WINNER  \
# 0  Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1          Chennai Super Kings           bat          Chennai Super Kings
# 2             Rajasthan Royals           bat             Delhi Daredevils
# 3               Mumbai Indians           bat  Royal Challengers Bangalore
# 4              Deccan Chargers           bat        Kolkata Knight Riders
#
#    WIN_BY_RUNS  WIN_BY_WICKETS PLAYER_OF_MATCH
# ...

# %%
matches.to_csv('match_detail1.csv')
